# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
# This is a setting to make the plot a big enough and
# the grid lines do not distract the entire plot
plt.rcParams.update(plt.rcParamsDefault)
plt.rcParams.update({
  'font.size': 16,
  'grid.alpha': 0.25})

# %%
# df = pd.read_csv("/workspaces/ST22-0424/Pengantar_Sains_Data/gini_rasio_kaltim.csv")
df = pd.read_csv("D:\[02] College\Code\Github\ST22-0424\Pengantar_Sains_Data\gini_rasio_kaltim.csv")
df
# Out:
#     year  gini_ratio
# 0   2009       0.355
# 1   2010       0.344
# 2   2011       0.366
# 3   2012       0.353
# 4   2013       0.369
# 5   2014       0.336
# 6   2015       0.313
# 7   2016       0.314
# 8   2017       0.323
# 9   2018       0.350
# 10  2019       0.338
# 11  2020       0.333
# 12  2021       0.339
# 13  2022       0.334
# 14  2023       0.328

# %%
gini_ratio_avg = np.mean(df["gini_ratio"])
gini_ratio_avg
gini_ratio_std = np.std(df["gini_ratio"])
gini_ratio_std
gini_ratio_var = np.var(df["gini_ratio"])
gini_ratio_var
print(f"Rerata:{gini_ratio_avg} Stdev : {gini_ratio_std}  Varians :{gini_ratio_var}")
# Out:
# Rerata:0.33966666666666673 Stdev : 0.016267213105575953  Varians :0.000264622222222222

# %%
fig, ax = plt.subplots(figsize=(8, 4))

ax.plot(df["year"], df["gini_ratio"], marker="o", markersize=4, 
      markerfacecolor="w", markeredgewidth=2, linewidth=2)
ax.axhline(y=gini_ratio_avg, color="r", alpha=0.4)

ax.set_title("Gini ratio of Balikpapan")
ax.grid("on")
ax.set_xlabel("Year")
ax.set_ylabel("Gini ratio")
plt.show(fig)
